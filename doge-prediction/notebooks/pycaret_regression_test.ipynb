# %%
import pandas as pd

# %%
df = pd.read_csv('doge_processed.csv')

# %%
df.sample(5)
# Out:
#      Date      Volume      Mean
# 204     6   708156957  0.067115
# 349     4  2957002544  0.123470
# 108     1   491414294  0.117424
# 142     0  1515679359  0.142285
# 45      1   541922892  0.169855

# %%
from pycaret.regression import *

# %%
s = setup(df, target='Mean')
# Out:
# <style type="text/css">
# #T_c9d27_row7_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c9d27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9d27_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c9d27_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9d27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9d27_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c9d27_row0_col1" class="data row0 col1" >7978</td>
#     </tr>
#     <tr>
#       <th id="T_c9d27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9d27_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c9d27_row1_col1" class="data row1 col1" >Mean</td>
#     </tr>
#     <tr>
#       <th id="T_c9d27_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_01475 th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
best_model
# Out:
# LGBMRegressor(random_state=7978)

# %%
predict_model(best_model, data=df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc485">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc485_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bc485_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bc485_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bc485_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bc485_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bc485_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bc485_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc485_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc485_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_bc485_row0_col1" class="data row0 col1" >0.0250</td>
# ...
