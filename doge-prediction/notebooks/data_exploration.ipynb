# %%
import pandas as pd

# %%
df = pd.read_csv('./data/doge-usd.csv')

# %%
df
# Out:
#            Date      Open      High       Low     Close  Adj Close      Volume
# 0    2021-11-20  0.233174  0.235953  0.225451  0.233024   0.233024   805305660
# 1    2021-11-21  0.233255  0.233350  0.225680  0.226328   0.226328   751789838
# 2    2021-11-22  0.226160  0.227531  0.216898  0.219676   0.219676   921753721
# 3    2021-11-23  0.219666  0.236201  0.214566  0.226512   0.226512  1907278849
# 4    2021-11-24  0.226680  0.230245  0.211836  0.221825   0.221825  1957665360
# ..          ...       ...       ...       ...       ...        ...         ...
# 361  2022-11-16  0.086964  0.090659  0.083986  0.085583   0.085583   712826081
# 362  2022-11-17  0.085594  0.086954  0.083178  0.084765   0.084765   461654197
# 363  2022-11-18  0.084764  0.086504  0.083805  0.084672   0.084672   337485766
# 364  2022-11-19  0.084672  0.084905  0.083387  0.084581   0.084581   246661551
# 365  2022-11-20  0.084575  0.085682  0.079348  0.079640   0.079640   431520160
#
# [366 rows x 7 columns]

# %%
mean_day = ((df['Open'] + df['High'] + df['Low'] + df['Close']) / 4)

# %%
type(mean_day)
# Out:
# pandas.core.series.Series

# %%
indexed_data = list(zip(mean_day.index, mean_day))

# %%
indexed_data
# Out:
# [(0, 0.23190049999999998),
#  (1, 0.22965325),
#  (2, 0.22256625),
#  (3, 0.22423625000000003),
#  (4, 0.22264650000000002),
#  (5, 0.21914625000000001),
#  (6, 0.20850925000000003),
#  (7, 0.20431500000000002),
#  (8, 0.20332575),
#  (9, 0.21239075),
#  (10, 0.21749174999999998),
#  (11, 0.212192),
#  (12, 0.21109549999999996),
#  (13, 0.20368024999999998),
#  (14, 0.17814925),
#  (15, 0.1734),
#  (16, 0.172467),
#  (17, 0.17855575),
#  (18, 0.1776395),
#  (19, 0.17495475),
#  (20, 0.16814075),
#  (21, 0.16635375),
#  (22, 0.16939825),
#  (23, 0.162514),
#  (24, 0.17817525),
#  (25, 0.183659),
#  (26, 0.17805325),
#  (27, 0.17030325),
#  (28, 0.17065450000000001),
#  (29, 0.17146725000000002),
#  (30, 0.16729375),
#  (31, 0.16918025),
#  (32, 0.17349575),
#  (33, 0.17849025000000002),
#  (34, 0.18666300000000002),
#  (35, 0.18945399999999998),
#  (36, 0.18969475),
#  (37, 0.18946325),
#  (38, 0.18064675),
#  (39, 0.17148975),
#  (40, 0.17015049999999998),
#  (41, 0.1711035),
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(*zip(*(indexed_data)))

# %%
df['Mean'] = mean_day

# %%
df.sample(5)
# Out:
#            Date      Open      High       Low     Close  Adj Close     Volume  \
# 361  2022-11-16  0.086964  0.090659  0.083986  0.085583   0.085583  712826081
# 71   2022-01-30  0.143057  0.143515  0.138754  0.139471   0.139471  363976741
# 253  2022-07-31  0.069642  0.072028  0.068054  0.068272   0.068272  521194035
# 217  2022-06-25  0.067110  0.069112  0.065384  0.068503   0.068503  432671864
# 113  2022-03-13  0.115080  0.116231  0.110686  0.111608   0.111608  373430106
#
#          Mean
# 361  0.086798
# 71   0.141199
# 253  0.069499
# 217  0.067527
# 113  0.113401

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 6)
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

plt.hist(df['Mean'], bins=100);

# %%
df.drop(['Date', 'Open', 'Close', 'High', 'Low', 'Adj Close'], axis=1)
# Out:
#          Volume      Mean
# 0     805305660  0.231900
# 1     751789838  0.229653
# 2     921753721  0.222566
# 3    1907278849  0.224236
# 4    1957665360  0.222647
# ..          ...       ...
# 361   712826081  0.086798
# 362   461654197  0.085123
# 363   337485766  0.084936
# 364   246661551  0.084386
# 365   431520160  0.082311
#
# [366 rows x 2 columns]

# %%
df
# Out:
#            Date      Open      High       Low     Close  Adj Close  \
# 0    2021-11-20  0.233174  0.235953  0.225451  0.233024   0.233024
# 1    2021-11-21  0.233255  0.233350  0.225680  0.226328   0.226328
# 2    2021-11-22  0.226160  0.227531  0.216898  0.219676   0.219676
# 3    2021-11-23  0.219666  0.236201  0.214566  0.226512   0.226512
# 4    2021-11-24  0.226680  0.230245  0.211836  0.221825   0.221825
# ..          ...       ...       ...       ...       ...        ...
# 361  2022-11-16  0.086964  0.090659  0.083986  0.085583   0.085583
# 362  2022-11-17  0.085594  0.086954  0.083178  0.084765   0.084765
# 363  2022-11-18  0.084764  0.086504  0.083805  0.084672   0.084672
# 364  2022-11-19  0.084672  0.084905  0.083387  0.084581   0.084581
# 365  2022-11-20  0.084575  0.085682  0.079348  0.079640   0.079640
#
#          Volume      Mean
# 0     805305660  0.231900
# 1     751789838  0.229653
# 2     921753721  0.222566
# 3    1907278849  0.224236
# ...

# %%
# are those two remaining columns correlated?

# %%
df['Volume'].corr(df['Mean'])
# Out:
# 0.3073049492179644

# %%
# apropox 0.31 so there is some correlation

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_61857/2760862483.py in <cell line: 1>()
# ----> 1 df['Date'].corr(df['Mean'])
#
# ~/Desktop/asi/project/venv/lib/python3.10/site-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2758
#    2759         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2760             return nanops.nancorr(
#    2761                 this.values, other.values, method=method, min_periods=min_periods
#    2762             )
#
# ~/Desktop/asi/project/venv/lib/python3.10/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ...

# %%
import datetime

# %%
df['DayOfWeek'] = df['Date'].map(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d')).dt.dayofweek

# %%
df
# Out:
#            Date      Open      High       Low     Close  Adj Close  \
# 0    2021-11-20  0.233174  0.235953  0.225451  0.233024   0.233024
# 1    2021-11-21  0.233255  0.233350  0.225680  0.226328   0.226328
# 2    2021-11-22  0.226160  0.227531  0.216898  0.219676   0.219676
# 3    2021-11-23  0.219666  0.236201  0.214566  0.226512   0.226512
# 4    2021-11-24  0.226680  0.230245  0.211836  0.221825   0.221825
# ..          ...       ...       ...       ...       ...        ...
# 361  2022-11-16  0.086964  0.090659  0.083986  0.085583   0.085583
# 362  2022-11-17  0.085594  0.086954  0.083178  0.084765   0.084765
# 363  2022-11-18  0.084764  0.086504  0.083805  0.084672   0.084672
# 364  2022-11-19  0.084672  0.084905  0.083387  0.084581   0.084581
# 365  2022-11-20  0.084575  0.085682  0.079348  0.079640   0.079640
#
#          Volume      Mean  DayOfWeek
# 0     805305660  0.231900          5
# 1     751789838  0.229653          6
# 2     921753721  0.222566          0
# ...

# %%
df['DayOfWeek'].corr(df['Mean'])
# Out:
# -0.0033959356485391314
